# %% [markdown]
# # Project 3 - Black-Box Policy Optimization

# %% [markdown]
# ### Install necessary libraries and import packages

# %%
# !wget  -q https://sites.google.com/a/g.clemson.edu/cpsc-drl/assignments/hw3/project3.zip
# !unzip -q project3.zip

# %%
# !apt-get update
# !apt-get install xvfb
# !apt-get install x11-utils
# !apt-get install ffmpeg
# !apt-get install python-opengl 
# !pip -q install gym pyvirtualdisplay pygame
# !pip3 install box2d-py


# Environment
import gym # OpenAI gym 
import frogger_env
gym.logger.set_level(40) # suppress warnings on gym

# Models and computation
import torch # will use pyTorch to handle NN 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import random
from random import sample

from collections import deque
import math

# Visualization
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display
from gym.wrappers import Monitor
import base64

# IO
from pathlib import Path
import os
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,745 kB]
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [893 kB]
# Fetched 2,906 kB in 6s (479 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.8).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# x11-utils is already the newest version (7.7+3build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-opengl is already the newest version (3.1.0+dfsg-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.7/dist-packages (2.3.8)

# %% [markdown]
# ### Some useful functions

# %%
#Let's define a simple helper function for visualization of episodes
def show_video(path):
    html = []
    for mp4 in Path(path).glob("*.mp4"):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append('''<video alt="{}" autoplay 
                      controls style="height: 400px;">
                      <source src="data:video/mp4;base64,{}" type="video/mp4" />
                 </video>'''.format(mp4, video_b64.decode('ascii')))
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
from google.colab import drive
from google.colab import files

def save_checkpoint(model, filename, mode=0):
    """
    Save a model to a file in your colab space 
        
    Parameters
    ----------
    model: your policy network
    filename: the name of the checkpoint file
    mode (int): determines where to store the file
                --> 0: collab space 1: Google Drive
    """
    if mode == 1: 
      drive.mount('/content/gdrive')
      path = F"/content/gdrive/My Drive/{filename}" 
      torch.save(model.state_dict(), path)
    else:
      torch.save(model.state_dict(), filename)

def export_to_local_drive(filename):
    """
    Download a file to your local machine 
        
    Parameters
    ----------
    filename: the name of the file
    """
    files.download(filename)

# %% [markdown]
# # Q1. CEM
#
# Implement below the cross-entropy method to solve the reacher-v0 environment and enable the agent to learn to navigate to a fixed goal position on a static highway map. Please, refer to the project descriprtion and lecture 13 for more details.

# %% [markdown]
# Let's first test things out!

# %%
display = Display(visible=0, size=(600, 400))
display.start()

env = gym.make("reacher-v0")
env = Monitor(env, './video', force=True, video_callable=lambda episode: True)
env.reset()
done = False
while not done:
    action = 2
    obs, reward, done, info = env.step(action)
env.close()
show_video('./video')
# Out:
# Origin:  [0.0, 0.0]
# world_width:  50.0
# world_height:  50.0
# Screen:  <Surface(600x600x32 SW)>
# <video alt="video/openaigym.video.2.3450.video000000.mp4" autoplay
#                       controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %% [markdown]
# The observation that the agent receives is its position, the goal position, and a unit vector that points from the agent's position to the goal.
#
# The action space consists of four actions 0: move up, 1: move down, 2: move right 3: move left

# %%
print('observation space:', env.observation_space.shape[0])
print('action space:', env.action_space.n)
# Out:
# observation space: 6
# action space: 4

# %% [markdown]
# ## Implement a policy network that the agent can use to select actions.
# Instead of training the parameters of the network, you will directly set them based on your CEM optimization.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

######################## Your code ####################################
class Agent(nn.Module): 
    def __init__(self, env, h_size=48):
        super(Agent, self).__init__()
        self.env = env
        # state, hidden layer, action sizes
        self.s_size = env.observation_space.shape[0]
        self.h_size = h_size
        self.a_size = env.action_space.n
        # define layers
        self.fc1 = nn.Linear(self.s_size, self.h_size)
        self.fc2 = nn.Linear(self.h_size, self.a_size)

    def set_weights(self, weights):
        s_size = self.s_size
        h_size = self.h_size
        a_size = self.a_size
        # separate the weights for each layer
        fc1_end = (s_size*h_size)+h_size
        fc1_W = torch.from_numpy(weights[:s_size*h_size].reshape(s_size, h_size))
        fc1_b = torch.from_numpy(weights[s_size*h_size:fc1_end])
        fc2_W = torch.from_numpy(weights[fc1_end:fc1_end+(h_size*a_size)].reshape(h_size, a_size))
        fc2_b = torch.from_numpy(weights[fc1_end+(h_size*a_size):])
        # set the weights for each layer
        self.fc1.weight.data.copy_(fc1_W.view_as(self.fc1.weight.data))
        self.fc1.bias.data.copy_(fc1_b.view_as(self.fc1.bias.data))
        self.fc2.weight.data.copy_(fc2_W.view_as(self.fc2.weight.data))
        self.fc2.bias.data.copy_(fc2_b.view_as(self.fc2.bias.data))

    def get_weights_dim(self):
        """
        Returns the number of the NN parameters (weights, biases)
        """
        # print(self.s_size, self.fc1_units, self.fc2_units, self.a_size)
        return (self.s_size+1)*self.h_size + (self.h_size+1)*self.a_size

    def forward(self, x):

        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x.cpu().data
    
    def greedy_action(self, state):
 
        with torch.no_grad():
            q_values = self.forward(state).detach().numpy().squeeze()
        action = np.argmax(q_values)
        return action

    def evaluate(self, weights, gamma=1.0, max_t=5000):
        self.set_weights(weights)
        episode_return = 0.0
        state = self.env.reset()
        done = False
        for t in range(max_t):
            state = torch.from_numpy(state).float().to(device)
            
            action = self.greedy_action(state)
            state, reward, done, _ = self.env.step(action)
            
            episode_return += reward * math.pow(gamma, t)
            if reward == 1:
                print('Reached in this episode')
                
            if done:
                break
        return episode_return

env = gym.make("reacher-v0")
agent = Agent(env).to(device)

# %% [markdown]
# ## Train a CEM agent

# %%
def cem_train(n_iterations=400, max_t = 100, gamma=1, print_every=1, pop_size=100, elite_frac=0.1, sigma=1.0, seed=12):
    torch.manual_seed(seed)
    np.random.seed(seed)
    n_elite = int(pop_size*elite_frac)

    scores_deque = deque(maxlen=100)
    scores = []
    best_weight = sigma*np.random.randn(agent.get_weights_dim())
    # print(best_weight.shape)
    for i_iteration in range(1, n_iterations+1):
        # print(sigma)
        weights_pop = [best_weight + (sigma*np.random.randn(agent.get_weights_dim())) for i in range(pop_size)]
        rewards = np.array([agent.evaluate(weights, gamma, max_t) for weights in weights_pop])
        
        elite_idxs = rewards.argsort()[-n_elite:]
        elite_weights = [weights_pop[i] for i in elite_idxs]
        # elite_rewards = [weights_pop[i] for i in elite_idxs]
        # print(elite_weights)
        best_weight = np.array(elite_weights).mean(axis=0)
        # print(best_weight)
        reward = agent.evaluate(best_weight, gamma=1.0)
        scores_deque.append(reward)
        scores.append(reward)
        sigma = np.array(elite_weights).std(axis=0)


        if i_iteration % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(i
# Episode 260	Average Score: -0.09
# Episode 261	Average Score: -0.09
# Episode 262	Average Score: -0.09
# Episode 263	Average Score: -0.09
# Episode 264	Average Score: -0.09
# Episode 265	Average Score: -0.09
# Episode 266	Average Score: -0.09
# Episode 267	Average Score: -0.09
# Episode 268	Average Score: -0.09
# Episode 269	Average Score: -0.09
# Episode 270	Average Score: -0.09
# Episode 271	Average Score: -0.09
# Episode 272	Average Score: -0.09
# Episode 273	Average Score: -0.09
# Episode 274	Average Score: -0.09
# Episode 275	Average Score: -0.09
# Episode 276	Average Score: -0.09
# Episode 277	Average Score: -0.09
# Episode 278	Average Score: -0.09
# Episode 279	Average Score: -0.09
# Episode 280	Average Score: -0.09
# Episode 281	Average Score: -0.09
# Episode 282	Average Score: -0.09
# Episode 283	Average Score: -0.09
# Episode 284	Average Score: -0.09
# Episode 285	Average Score: -0.09
# Episode 286	Average Score: -0.09
# Episode 287	Average Score: -0.09
# Episode 288	Average Score: -0.09
# Episode 289	Average Score: -0.09
# Episode 290	Average Score: -0.09
# Episode 291	Average Score: -0.09
# Episode 292	Average Score: -0.09
# Episode 293	Average Score: -0.09
# Episode 294	Average Score: -0.09
# Episode 295	Average Score: -0.09
# Episode 296	Average Score: -0.09
# Episode 297	Average Score: -0.09
# Episode 298	Average Score: -0.09
# Episode 299	Average Score: -0.09
# Episode 300	Average Score: -0.09
# Episode 301	Average Score: -0.09
# Episode 302	Average Score: -0.09
# Episode 303	Average Score: -0.09
# Episode 304	Average Score: -0.09
# Episode 305	Average Score: -0.09
# Episode 306	Average Score: -0.09
# Episode 307	Average Score: -0.09
# Episode 308	Average Score: -0.09
# Episode 309	Average Score: -0.09
# Episode 310	Average Score: -0.09
# Episode 311	Average Score: -0.09
# Episode 312	Average Score: -0.09
# Episode 313	Average Score: -0.09
# Episode 314	Average Score: -0.09
# Episode 315	Average Score: -0.09
# Episode 316	Average Score: -0.09
# Episode 317	Average Score: -0.09
# Episode 318	Average Score: -0.09
# Episode 319	Average Score: -0.09
# Episode 320	Average Score: -0.09
# Episode 321	Average Score: -0.09
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-5c3a7ac8ee01> in <module>()
#      35     return scores
#      36
# ---> 37 scores = cem_train()
#      38 # plot the scores
#      39 fig = plt.figure()
#
# <ipython-input-57-5c3a7ac8ee01> in cem_train(n_iterations, max_t, gamma, print_every, pop_size, elite_frac, sigma, seed)
#      12         # print(sigma)
#      13         weights_pop = [best_weight + (sigma*np.random.randn(agent.get_weights_dim())) for i in range(pop_size)]
# ---> 14         rewards = np.array([agent.evaluate(weights, gamma, max_t) for weights in weights_pop])
#      15
#      16         elite_idxs = rewards.argsort()[-n_elite:]
#
# <ipython-input-57-5c3a7ac8ee01> in <listcomp>(.0)
#      12         # print(sigma)
#      13         weights_pop = [best_weight + (sigma*np.random.randn(agent.get_weights_dim())) for i in range(pop_size)]
# ---> 14         rewards = np.array([agent.evaluate(weights, gamma, max_t) for weights in weights_pop])
#      15
#      16         elite_idxs = rewards.argsort()[-n_elite:]
#
# <ipython-input-52-9c3053a93af2> in evaluate(self, weights, gamma, max_t)
#     147
#     148             action = self.greedy_action(state)
# --> 149             state, reward, done, _ = self.env.step(action)
#     150
#     151             episode_return += reward * math.pow(gamma, t)
#
# /content/frogger_env/envs/abstract.py in step(self, action)
#     241
#     242         self.steps += 1
# --> 243         self._simulate(action)
#     244
#     245         self.observation_history.append(self.observation_type.observe())
#
# /content/frogger_env/envs/abstract.py in _simulate(self, action)
#     280             self.agent.step(1 / self.config["simulation_frequency"])
#     281             # update the vehicles
# --> 282             self.road.step(1 / self.config["simulation_frequency"])
#     283             self.agent.check_collision(self.road.vehicles)
#     284
#
# /content/frogger_env/agent/road.py in step(self, dt)
#     188         """
#     189         for v in self.vehicles:
# --> 190             v.step(dt)
#     191
#     192     def get_last_lane_Y(self):
#
# /content/frogger_env/agent/road.py in step(self, dt)
#      75         Update the vehicle state given its speed.
#      76         """
# ---> 77         self.position += np.array([self.speed, 0]) * dt * self.lane.direction
#      78         if self.lane.direction == 1:
#      79             if self.position[0] - self.length > self.lane.end[0]:  # reset the vehicle
#
# KeyboardInterrupt:

# %%
cem_score, cem_total_steps, cem_episode_steps = result.T

fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
plt.plot(cem_score)
plt.ylabel('Reward')
plt.xlabel('Episode #')
ax1.set_title('Avg Reward')

fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
plt.plot(cem_total_steps)
plt.ylabel('Total Steps')
plt.xlabel('Episode #')
ax2.set_title('Total Steps')

fig3 = plt.figure()
ax3 = fig3.add_subplot(111)
plt.plot(cem_episode_steps)
plt.ylabel('CEM Steps')
plt.xlabel('Episode #')
ax3.set_title('CEM Steps')
# Out:
# Text(0.5, 1.0, 'CEM Steps')

# %%
env = gym.make("reacher-v0")
env = Monitor(env, './video', force=True, video_callable=lambda episode: True)
env.reset()
done = False
agent.load_state_dict(torch.load('checkpoint.pth'))
state = env.reset()
while True:
    state = torch.from_numpy(state).float().to(device)
    
    action = agent.greedy_action(state)
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break
env.close()
show_video('./video')

# %% [markdown]
# # Q2. ES
#
# Implement below the non-distributed version of the evolution strategies method from  [[Salimans et al., 2017]](https://arxiv.org/pdf/1703.03864.pdf) to solve the LunarLanderContinuous-v2 environment and enable the agent to navigate to its landing pad. Please, refer to the project descriprtion and lecture 13 for more details.

# %% [markdown]
# First, let's test the new environment out!

# %%
display = Display(visible=0, size=(900, 400))
display.start()

env = gym.make("LunarLanderContinuous-v2")
env = Monitor(env, './video', force=True, video_callable=lambda episode: True)
env.reset()
done = False
i = 0
while not done:
    action = env.action_space.sample()
    print(i)
    obs, reward, done, info = env.step(action)
    i+=1
env.close()
show_video('./video')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2872d8babd06> in <module>()
# ----> 1 display = Display(visible=0, size=(900, 400))
#       2 display.start()
#       3
#       4 env = gym.make("LunarLanderContinuous-v2")
#       5 env = Monitor(env, './video', force=True, video_callable=lambda episode: True)
#
# NameError: name 'Display' is not defined

# %% [markdown]
# The observation that the agent receives is its position, velocity, angular speed, and two 2 Boolean flags indicating whether the left and right leg of the agent, respectively, is in contact with the ground.
#
# Two continuous actions are used to control the agent. The first one controls the main engine and the second one controls the left and right engines. *The expected range of each of the two actions is [-1, 1]. Please make sure that your policy network outputs values in that range*

# %%
print('observation space:', env.observation_space)
print('action space:', env.action_space)
print('solved_score', env.spec.reward_threshold)

# %% [markdown]
# ## Implement a policy network that the agent can use to select actions.
# Instead of training the parameters of the network, you will directly set them based on your ES optimization.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

######################## Your code ####################################
class ESAgent(nn.Module): 
    def __init__(self, env, h_size=256):
        super(ESAgent, self).__init__()
        self.env = env
        # state, hidden layer, action sizes
        self.s_size = env.observation_space.shape[0]
        self.h_size = h_size
        self.a_size = env.action_space.shape[0]
        # define layers
        self.fc1 = nn.Linear(self.s_size, self.h_size)
        self.fc2 = nn.Linear(self.h_size, self.a_size)

    def forward(self, x):
        """
        Perform forward pass 
        """
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x.cpu().data
    
    def get_weights_dim(self):
        """
        Returns the number of the NN parameters (weights, biases)
        """
        return sum(p.numel() for p in self.parameters())
    
    def set_weights(self, weights):
        '''
        Function to copy a weight vector to the parameters (weights, biases) of the NN. 
        You can also set the weights outside of the class, e.g. using state_dict()

        Params
        ======
            weights (float): a flatten numpy array that contains the weight vector obtained through CEM
        '''
        s_size = self.s_size
        h_size = self.h_size
        a_size = self.a_size
        # separate the weights for each layer
        fc1_end = (s_size*h_size)+h_size
        fc1_W = torch.from_numpy(weights[:s_size*h_size].reshape(s_size, h_size))
        fc1_b = torch.from_numpy(weights[s_size*h_size:fc1_end])
        fc2_W = torch.from_numpy(weights[fc1_end:fc1_end+(h_size*a_size)].reshape(h_size, a_size))
        fc2_b = torch.from_numpy(weights[fc1_end+(h_size*a_size):])
        # set the weights for each layer
        self.fc1.weight.data.copy_(fc1_W.view_as(self.fc1.weight.data))
        self.fc1.bias.data.copy_(fc1_b.view_as(self.fc1.bias.data))
        self.fc2.weight.data.copy_(fc2_W.view_as(self.fc2.weight.data))
        self.fc2.bias.data.copy_(fc2_b.view_as(self.fc2.bias.data))

    def get_weights_dim(self):
        """
        Returns the number of the NN parameters (weights, biases)
        """
        # print(self.s_size, self.fc1_units, self.fc2_units, self.a_size)
        return (self.s_size+1)*self.h_size + (self.h_size+1)*self.a_size

    def greedy_action(self, state):
        
        with torch.no_grad():
            action = self.forward(state).detach().numpy().squeeze()
        
        if action[0] > 1.0:
            action[0] = 1.0
        elif action[0] < -1.0:
            action[0] = -1
        elif action[1] > 1.0:
            action[1] = 1.0
        elif action[1] < -1.0:
            action[1] = -1.0

        return action

    def evaluate(self, weights, gamma=1.0, max_t=5000):
        self.set_weights(weights)
        episode_return = 0.0
        state = self.env.reset()
        done = False
        episode_step = 0
        for t in range(max_t):
            state = torch.from_numpy(state).float().to(device)
            
            action = self.greedy_action(state)
            state, reward, done, _ = self.env.step(action)
            
            episode_return += reward * math.pow(gamma, t)
            if reward == 1:
                print('Reached in this episode')
                
            if done:
                break
            episode_step += 1
        return episode_return, episode_step

env = gym.make("LunarLanderContinuous-v2")
es_agent = ESAgent(env).to(device)

# %% [markdown]
# ## Train an ES agent

# %%
def es_train(n_iterations=1000, max_t = 1000, gamma=1, print_every=1, pop_size=50, sigma=0.5, seed=2, alpha = 1e-3):
    torch.manual_seed(seed)
    np.random.seed(seed)
    best_weight = sigma*np.random.randn(es_agent.get_weights_dim())
    scores_deque = deque(maxlen=100)
    scores = []
    i_iteration = 0
    total_steps = 0
    result = np.empty((n_iterations, 3))
    result[:] = np.nan 
    for i_iteration in range(n_iterations):
        epsilon = [np.random.randn(es_agent.get_weights_dim()) for i in range(pop_size)]
        weights_pop = [best_weight + (sigma*epsilon[i]) for i in range(pop_size)]
        rewards = np.array([es_agent.evaluate(weights, gamma, max_t)[0] for weights in weights_pop])
        total_reward_epsilon = np.zeros(es_agent.get_weights_dim())

        for i in range(pop_size):
            total_reward_epsilon += rewards[i]*epsilon[i]

        best_weight = best_weight + (alpha/(pop_size*sigma) * total_reward_epsilon)
        reward, episode_steps = es_agent.evaluate(best_weight, gamma=1.0)


        scores_deque.append(reward)
        scores.append(reward)
        i_iteration += 1
        total_steps += episode_steps
        result[i_iteration-1] = reward, total_steps, episode_steps
        print('Episode {}\tAverage Score: {:.2f}'.format(i_iteration, np.mean(scores_deque)))

        if np.mean(scores_deque)>= env.spec.reward_threshold:
            print('\nEnvironment solved in {:d} iterations!\tAverage Score: {:.2f}'.format(i_iteration, np.mean(scores_deque)))
            break
        

        
    torch.save(es_agent.state_dict(), 'checkpoint_es.pth')
    return result 

result = es_train()
# Out:
# Episode 1	Average Score: -585.64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e579c3763848> in <module>()
#      39     return result
#      40
# ---> 41 result = es_train()
#      42
#      43
#
# <ipython-input-8-e579c3763848> in es_train(n_iterations, max_t, gamma, print_every, pop_size, sigma, seed, alpha)
#      13         epsilon = [np.random.randn(es_agent.get_weights_dim()) for i in range(pop_size)]
#      14         weights_pop = [best_weight + (sigma*epsilon[i]) for i in range(pop_size)]
# ---> 15         rewards = np.array([es_agent.evaluate(weights, gamma, max_t)[0] for weights in weights_pop])
#      16         total_reward_epsilon = np.zeros(es_agent.get_weights_dim())
#      17
#
# <ipython-input-8-e579c3763848> in <listcomp>(.0)
#      13         epsilon = [np.random.randn(es_agent.get_weights_dim()) for i in range(pop_size)]
#      14         weights_pop = [best_weight + (sigma*epsilon[i]) for i in range(pop_size)]
# ---> 15         rewards = np.array([es_agent.evaluate(weights, gamma, max_t)[0] for weights in weights_pop])
#      16         total_reward_epsilon = np.zeros(es_agent.get_weights_dim())
#      17
#
# <ipython-input-7-de971bf11ae5> in evaluate(self, weights, gamma, max_t)
#      85
#      86             action = self.greedy_action(state)
# ---> 87             state, reward, done, _ = self.env.step(action)
#      88
#      89             episode_return += reward * math.pow(gamma, t)
#
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/time_limit.py in step(self, action)
#      14     def step(self, action):
#      15         assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16         observation, reward, done, info = self.env.step(action)
#      17         self._elapsed_steps += 1
#      18         if self._elapsed_steps >= self._max_episode_steps:
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/box2d/lunar_lander.py in step(self, action)
#     292             impulse_pos = (self.lander.position[0] + ox - tip[0] * 17/SCALE,
#     293                            self.lander.position[1] + oy + tip[1] * SIDE_ENGINE_HEIGHT/SCALE)
# --> 294             p = self._create_particle(0.7, impulse_pos[0], impulse_pos[1], s_power)
#     295             p.ApplyLinearImpulse((ox * SIDE_ENGINE_POWER * s_power, oy * SIDE_ENGINE_POWER * s_power),
#     296                                  impulse_pos
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/box2d/lunar_lander.py in _create_particle(self, mass, x, y, ttl)
#     233                 categoryBits=0x0100,
#     234                 maskBits=0x001,  # collide only with ground
# --> 235                 restitution=0.3)
#     236                 )
#     237         p.ttl = ttl
#
# /usr/local/lib/python3.7/dist-packages/Box2D/Box2D.py in CreateDynamicBody(self, **kwargs)
#    6047         """
#    6048         kwargs['type'] = b2_dynamicBody
# -> 6049         return self.CreateBody(**kwargs)
#    6050
#    6051     def CreateKinematicBody(self, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/Box2D/Box2D.py in CreateBody(self, defn, **kwargs)
#    6098                 raise TypeError('Expected b2BodyDef')
#    6099         else:
# -> 6100             defn = b2BodyDef(**kwargs)
#    6101
#    6102         body=self.__CreateBody(defn)
#
# /usr/local/lib/python3.7/dist-packages/Box2D/Box2D.py in __init__(self, **kwargs)
#    3778     def __init__(self, **kwargs):
#    3779         _Box2D.b2BodyDef_swiginit(self,_Box2D.new_b2BodyDef())
# -> 3780         _init_kwargs(self, **kwargs)
#    3781
#    3782
#
# /usr/local/lib/python3.7/dist-packages/Box2D/Box2D.py in _init_kwargs(self, **kwargs)
#     150
#     151         try:
# --> 152             setattr(self, key, value)
#     153         except Exception as ex:
#     154             raise ex.__class__('Failed on kwargs for %s.%s: %s' \
#
# /usr/local/lib/python3.7/dist-packages/Box2D/Box2D.py in fixtures(self, fixtures)
#    3837     @fixtures.setter
#    3838     def fixtures(self, fixtures):
# -> 3839         if isinstance(fixtures, b2FixtureDef):
#    3840             self._fixtures = [fixtures]
#    3841         else:
#
# KeyboardInterrupt:

# %%
es_score, es_total_steps, es_episode_steps = result.T

fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
plt.plot(es_score)
plt.ylabel('Reward')
plt.xlabel('Episode #')
ax1.set_title('Avg Reward')

fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
plt.plot(es_total_steps)
plt.ylabel('Total Steps')
plt.xlabel('Episode #')
ax2.set_title('Total Steps')

fig3 = plt.figure()
ax3 = fig3.add_subplot(111)
plt.plot(es_episode_steps)
plt.ylabel('CEM Steps')
plt.xlabel('Episode #')
ax3.set_title('CEM Steps')
# Out:
# Text(0.5, 1.0, 'CEM Steps')

# %%
display = Display(visible=0, size=(900, 400))
display.start()

env = gym.make("LunarLanderContinuous-v2")
env = Monitor(env, './video', force=True, video_callable=lambda episode: True)

done = False
es_agent.load_state_dict(torch.load('checkpoint_es.pth'))
state = env.reset()
while True:
    state = torch.from_numpy(state).float().to(device)
    
    action = es_agent.greedy_action(state)
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break
env.close()
show_video('./video')
# Out:
# <video alt="video/openaigym.video.1.3450.video000000.mp4" autoplay
#                       controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %%
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6459d04d738f> in <module>()
# ----> 1 print(result)
#
# NameError: name 'result' is not defined
